# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.environ.get('GOOGLE_API_KEY')
if not api_key:
    raise ValueError('No API key found')
else:
    print('API key found')
# Out:
# API key found

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash"
)

# %%
messages = [
    ("human", "Am I cute?"),
]
ai_msg = llm.invoke(messages)
ai_msg.content
# Out:
# 'Whether or not someone is considered "cute" is completely subjective! It\'s based on personal preferences and what different people find appealing. There\'s no universal standard for cuteness.\n\nInstead of worrying about whether you fit someone else\'s idea of cute, focus on being yourself and the qualities you like about yourself. Confidence and kindness are almost always attractive!'
